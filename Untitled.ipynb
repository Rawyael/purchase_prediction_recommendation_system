# %% [markdown]
# # Imports:

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sales_data = pd.read_csv('E-commerece_sales_data_2024.csv')
sales_data
# Out:
#       user id                        product id Interaction type  \
# 0         1.0  4c69b61db1fc16e7013b43fc926e502d         purchase
# 1         2.0  66d49bbed043f5be260fa9f7fbff5957             view
# 2         3.0  2c55cae269aebf53838484b0d7dd931a             like
# 3         4.0  18018b6bc416dab347b1b7db79994afa             view
# 4         5.0  e04b990e95bf73bbe6a3fa09785d7cd0             like
# ...       ...                               ...              ...
# 3289      NaN                               NaN              NaN
# 3290      NaN                               NaN              NaN
# 3291      NaN                               NaN              NaN
# 3292      NaN                               NaN              NaN
# 3293      NaN                               NaN              NaN
#
#            Time stamp  Unnamed: 4
# 0     10/10/2023 8:00         NaN
# 1     11/10/2023 8:00         NaN
# 2     12/10/2023 8:00         NaN
# 3     13/10/2023 8:00         NaN
# ...

# %% [markdown]
# # Preprocessing (sales_data):

# %% [markdown]
# ## droping duplicates:

# %%
sales_data.columns
# Out:
# Index(['user id', 'product id', 'Interaction type', 'Time stamp',
#        'Unnamed: 4'],
#       dtype='object')

# %%
sales_data.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3289     True
# 3290     True
# 3291     True
# 3292     True
# 3293     True
# Length: 3294, dtype: bool

# %%
sales_data.duplicated().sum()
# Out:
# 294

# %%
sales_data = sales_data.drop_duplicates()
sales_data
# Out:
#       user id                        product id Interaction type  \
# 0         1.0  4c69b61db1fc16e7013b43fc926e502d         purchase
# 1         2.0  66d49bbed043f5be260fa9f7fbff5957             view
# 2         3.0  2c55cae269aebf53838484b0d7dd931a             like
# 3         4.0  18018b6bc416dab347b1b7db79994afa             view
# 4         5.0  e04b990e95bf73bbe6a3fa09785d7cd0             like
# ...       ...                               ...              ...
# 2995   2996.0  82318e8acf79bbeb3cf685a2732fb630             view
# 2996   2997.0  19d150365d798db47cccf1622b6ad754         purchase
# 2997   2998.0  136c0aff3ab56bd3d138775fe90ef970             view
# 2998   2999.0  a2c6dd69f022a658c5bcc2b3b52970f2             like
# 2999      NaN                               NaN              NaN
#
#            Time stamp  Unnamed: 4
# 0     10/10/2023 8:00         NaN
# 1     11/10/2023 8:00         NaN
# 2     12/10/2023 8:00         NaN
# 3     13/10/2023 8:00         NaN
# ...

# %% [markdown]
# ## missing data:

# %%
sales_data = sales_data.drop(columns = ['Unnamed: 4'])
sales_data
# Out:
#       user id                        product id Interaction type  \
# 0         1.0  4c69b61db1fc16e7013b43fc926e502d         purchase
# 1         2.0  66d49bbed043f5be260fa9f7fbff5957             view
# 2         3.0  2c55cae269aebf53838484b0d7dd931a             like
# 3         4.0  18018b6bc416dab347b1b7db79994afa             view
# 4         5.0  e04b990e95bf73bbe6a3fa09785d7cd0             like
# ...       ...                               ...              ...
# 2995   2996.0  82318e8acf79bbeb3cf685a2732fb630             view
# 2996   2997.0  19d150365d798db47cccf1622b6ad754         purchase
# 2997   2998.0  136c0aff3ab56bd3d138775fe90ef970             view
# 2998   2999.0  a2c6dd69f022a658c5bcc2b3b52970f2             like
# 2999      NaN                               NaN              NaN
#
#            Time stamp
# 0     10/10/2023 8:00
# 1     11/10/2023 8:00
# 2     12/10/2023 8:00
# 3     13/10/2023 8:00
# 4     14/10/2023 8:00
# ...               ...
# ...

# %%
sales_data.isnull().sum().sort_values(ascending=False)
# Out:
# Interaction type    129
# user id               1
# product id            1
# Time stamp            1
# dtype: int64

# %%
sales_data['Interaction type'] = sales_data['Interaction type'].fillna(sales_data['Interaction type'].mode()[0])
sales_data['Interaction type']
# Out:
# 0       purchase
# 1           view
# 2           like
# 3           view
# 4           like
#           ...
# 2995        view
# 2996    purchase
# 2997        view
# 2998        like
# 2999        like
# Name: Interaction type, Length: 3000, dtype: object

# %%
sales_data['Interaction type'] = sales_data['Interaction type'].fillna(sales_data['Interaction type'].mode()[0])

# %%
sales_data['Time stamp'] = sales_data['Time stamp'].fillna(sales_data['Time stamp'].mode()[0])
sales_data['Time stamp']
# Out:
# 0       10/10/2023 8:00
# 1       11/10/2023 8:00
# 2       12/10/2023 8:00
# 3       13/10/2023 8:00
# 4       14/10/2023 8:00
#              ...
# 2995    16/12/2023 8:00
# 2996    17/12/2023 8:00
# 2997    18/12/2023 8:00
# 2998    19/12/2023 8:00
# 2999    10/10/2023 8:00
# Name: Time stamp, Length: 3000, dtype: object

# %%
sales_data['product id'] = sales_data['product id'].fillna(sales_data['product id'].mode()[0])
sales_data['product id']
# Out:
# 0       4c69b61db1fc16e7013b43fc926e502d
# 1       66d49bbed043f5be260fa9f7fbff5957
# 2       2c55cae269aebf53838484b0d7dd931a
# 3       18018b6bc416dab347b1b7db79994afa
# 4       e04b990e95bf73bbe6a3fa09785d7cd0
#                       ...
# 2995    82318e8acf79bbeb3cf685a2732fb630
# 2996    19d150365d798db47cccf1622b6ad754
# 2997    136c0aff3ab56bd3d138775fe90ef970
# 2998    a2c6dd69f022a658c5bcc2b3b52970f2
# 2999    0000fe97fd6c7705b08b7f4c7c5312ce
# Name: product id, Length: 3000, dtype: object

# %%
sales_data['user id'] = sales_data['user id'].fillna(sales_data['user id'].mode()[0]).round().astype(int)
sales_data['user id']
# Out:
# 0          1
# 1          2
# 2          3
# 3          4
# 4          5
#         ...
# 2995    2996
# 2996    2997
# 2997    2998
# 2998    2999
# 2999       1
# Name: user id, Length: 3000, dtype: int64

# %%
sales_data[['Date', 'Time']] = sales_data['Time stamp'].str.split(' ', expand=True)
sales_data[['Date', 'Time']]
# Out:
#             Date  Time
# 0     10/10/2023  8:00
# 1     11/10/2023  8:00
# 2     12/10/2023  8:00
# 3     13/10/2023  8:00
# 4     14/10/2023  8:00
# ...          ...   ...
# 2995  16/12/2023  8:00
# 2996  17/12/2023  8:00
# 2997  18/12/2023  8:00
# 2998  19/12/2023  8:00
# 2999  10/10/2023  8:00
#
# [3000 rows x 2 columns]

# %%
sales_data
# Out:
#       user id                        product id Interaction type  \
# 0           1  4c69b61db1fc16e7013b43fc926e502d         purchase
# 1           2  66d49bbed043f5be260fa9f7fbff5957             view
# 2           3  2c55cae269aebf53838484b0d7dd931a             like
# 3           4  18018b6bc416dab347b1b7db79994afa             view
# 4           5  e04b990e95bf73bbe6a3fa09785d7cd0             like
# ...       ...                               ...              ...
# 2995     2996  82318e8acf79bbeb3cf685a2732fb630             view
# 2996     2997  19d150365d798db47cccf1622b6ad754         purchase
# 2997     2998  136c0aff3ab56bd3d138775fe90ef970             view
# 2998     2999  a2c6dd69f022a658c5bcc2b3b52970f2             like
# 2999        1  0000fe97fd6c7705b08b7f4c7c5312ce             like
#
#            Time stamp        Date  Time
# 0     10/10/2023 8:00  10/10/2023  8:00
# 1     11/10/2023 8:00  11/10/2023  8:00
# 2     12/10/2023 8:00  12/10/2023  8:00
# ...

# %%
sales_data = sales_data.drop(columns = ['Time stamp'])
sales_data
# Out:
#       user id                        product id Interaction type        Date  \
# 0           1  4c69b61db1fc16e7013b43fc926e502d         purchase  10/10/2023
# 1           2  66d49bbed043f5be260fa9f7fbff5957             view  11/10/2023
# 2           3  2c55cae269aebf53838484b0d7dd931a             like  12/10/2023
# 3           4  18018b6bc416dab347b1b7db79994afa             view  13/10/2023
# 4           5  e04b990e95bf73bbe6a3fa09785d7cd0             like  14/10/2023
# ...       ...                               ...              ...         ...
# 2995     2996  82318e8acf79bbeb3cf685a2732fb630             view  16/12/2023
# 2996     2997  19d150365d798db47cccf1622b6ad754         purchase  17/12/2023
# 2997     2998  136c0aff3ab56bd3d138775fe90ef970             view  18/12/2023
# 2998     2999  a2c6dd69f022a658c5bcc2b3b52970f2             like  19/12/2023
# 2999        1  0000fe97fd6c7705b08b7f4c7c5312ce             like  10/10/2023
#
#       Time
# 0     8:00
# 1     8:00
# ...

# %% [markdown]
# ## visualizing :

# %%
sns.countplot(data=sales_data, x='Interaction type')
# Out:
# <AxesSubplot:xlabel='Interaction type', ylabel='count'>

# %%
class_counts = sales_data['Interaction type'].value_counts()

# Print class counts
print(class_counts)

plt.bar(class_counts.index, class_counts.values)
# Out:
# like        1274
# view         871
# purchase     855
# Name: Interaction type, dtype: int64
# <BarContainer object of 3 artists>

# %% [markdown]
# # preprocessing (customer_data):

# %%
customer_data = pd.read_csv('customer_details.csv')
customer_data
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# 0                        53       Kentucky    L       Gray  Winter
# 1                        64          Maine    L     Maroon  Winter
# ...

# %% [markdown]
# ## droping duplicates:

# %%
customer_data.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3895    False
# 3896    False
# 3897    False
# 3898    False
# 3899    False
# Length: 3900, dtype: bool

# %%
customer_data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## missing data:

# %%
customer_data.isnull().sum().sort_values(ascending=False)
# Out:
# Customer ID               0
# Age                       0
# Payment Method            0
# Previous Purchases        0
# Promo Code Used           0
# Discount Applied          0
# Shipping Type             0
# Subscription Status       0
# Review Rating             0
# Season                    0
# Color                     0
# Size                      0
# Location                  0
# Purchase Amount (USD)     0
# Category                  0
# Item Purchased            0
# Gender                    0
# Frequency of Purchases    0
# dtype: int64

# %%
customer_data[['Purchase Amount (USD)']].boxplot()
# Out:
# <AxesSubplot:>

# %%
sns.countplot(data=customer_data, x='Category')
# Out:
# <AxesSubplot:xlabel='Category', ylabel='count'>

# %% [markdown]
# # preprocessing (product_data):

# %%
product_data = pd.read_csv('product_details.csv')
product_data
# Out:
#                                Uniqe Id  \
# 0      4c69b61db1fc16e7013b43fc926e502d
# 1      66d49bbed043f5be260fa9f7fbff5957
# 2      2c55cae269aebf53838484b0d7dd931a
# 3      18018b6bc416dab347b1b7db79994afa
# 4      e04b990e95bf73bbe6a3fa09785d7cd0
# ...                                 ...
# 9997   1a22f23576bfdfe5ed6c887dc117aab6
# 9998   e11514dcf1f087887cd5ea0bd646d1fc
# 9999   c00301a38560da2abc89c1f86ce4b267
# 10000  c2928dbf9796ceba44863a2736afb405
# 10001  2bb94aefc3467ed83860e0e2712d5f10
#
#                                             Product Name  Brand Name  Asin  \
# 0      DB Longboards CoreFlex Crossbow 41" Bamboo Fib...         NaN   NaN
# 1      Electronic Snap Circuits Mini Kits Classpack, ...         NaN   NaN
# 2      3Doodler Create Flexy 3D Printing Filament Ref...         NaN   NaN
# 3      Guillow Airplane Design Studio with Travel Cas...         NaN   NaN
# 4                       Woodstock- Collage 500 pc Puzzle         NaN   NaN
# ...

# %% [markdown]
#  ## droping duplicates:

# %%
product_data.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 9997     False
# 9998     False
# 9999     False
# 10000    False
# 10001    False
# Length: 10002, dtype: bool

# %%
product_data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## missing data:

# %%
product_data.isnull().sum().sort_values(ascending=False)
# Out:
# Product Description      10002
# Sku                      10002
# Brand Name               10002
# Asin                     10002
# Size Quantity Variant    10002
# List Price               10002
# Direction To Use         10002
# Quantity                 10002
# Ingredients              10002
# Color                    10002
# Dimensions               10002
# Product Details          10002
# Stock                    10002
# Upc Ean Code              9968
# Product Dimensions        9523
# Variants                  7524
# Model Number              1770
# Product Specification     1632
# Shipping Weight           1138
# Category                   830
# Technical Details          790
# About Product              273
# Selling Price              107
# Image                        0
# Product Name                 0
# Product Url                  0
# Is Amazon Seller             0
# Uniqe Id                     0
# dtype: int64

# %%
columns_to_drop = ['Product Description', 'Sku', 'Brand Name', 'Asin', 'Size Quantity Variant',
                   'List Price', 'Direction To Use', 'Quantity', 'Ingredients', 'Color',
                   'Dimensions', 'Product Details', 'Stock', 'Upc Ean Code', 'Product Dimensions',
                   'Variants', 'Model Number', 'Product Specification', 'Shipping Weight']
product_data = product_data.drop(columns=columns_to_drop)

# %%
product_data
# Out:
#                                Uniqe Id  \
# 0      4c69b61db1fc16e7013b43fc926e502d
# 1      66d49bbed043f5be260fa9f7fbff5957
# 2      2c55cae269aebf53838484b0d7dd931a
# 3      18018b6bc416dab347b1b7db79994afa
# 4      e04b990e95bf73bbe6a3fa09785d7cd0
# ...                                 ...
# 9997   1a22f23576bfdfe5ed6c887dc117aab6
# 9998   e11514dcf1f087887cd5ea0bd646d1fc
# 9999   c00301a38560da2abc89c1f86ce4b267
# 10000  c2928dbf9796ceba44863a2736afb405
# 10001  2bb94aefc3467ed83860e0e2712d5f10
#
#                                             Product Name  \
# 0      DB Longboards CoreFlex Crossbow 41" Bamboo Fib...
# 1      Electronic Snap Circuits Mini Kits Classpack, ...
# 2      3Doodler Create Flexy 3D Printing Filament Ref...
# 3      Guillow Airplane Design Studio with Travel Cas...
# 4                       Woodstock- Collage 500 pc Puzzle
# ...                                                  ...
# 9997   Remedia Publications REM536B Money Activity Bo...
# ...

# %%
columns_to_fill = ['Uniqe Id', 'Product Name', 'Category', 'Selling Price', 'About Product', 
                   'Technical Details', 'Image', 'Product Url', 'Is Amazon Seller']

# Fill missing values in specified columns with mode
product_data[columns_to_fill] = product_data[columns_to_fill].fillna(product_data[columns_to_fill].mode().iloc[0])

# %%
product_data
# Out:
#                                Uniqe Id  \
# 0      4c69b61db1fc16e7013b43fc926e502d
# 1      66d49bbed043f5be260fa9f7fbff5957
# 2      2c55cae269aebf53838484b0d7dd931a
# 3      18018b6bc416dab347b1b7db79994afa
# 4      e04b990e95bf73bbe6a3fa09785d7cd0
# ...                                 ...
# 9997   1a22f23576bfdfe5ed6c887dc117aab6
# 9998   e11514dcf1f087887cd5ea0bd646d1fc
# 9999   c00301a38560da2abc89c1f86ce4b267
# 10000  c2928dbf9796ceba44863a2736afb405
# 10001  2bb94aefc3467ed83860e0e2712d5f10
#
#                                             Product Name  \
# 0      DB Longboards CoreFlex Crossbow 41" Bamboo Fib...
# 1      Electronic Snap Circuits Mini Kits Classpack, ...
# 2      3Doodler Create Flexy 3D Printing Filament Ref...
# 3      Guillow Airplane Design Studio with Travel Cas...
# 4                       Woodstock- Collage 500 pc Puzzle
# ...                                                  ...
# 9997   Remedia Publications REM536B Money Activity Bo...
# ...

# %%
product_data.isnull().sum().sort_values(ascending=False)
# Out:
# Uniqe Id             0
# Product Name         0
# Category             0
# Selling Price        0
# About Product        0
# Technical Details    0
# Image                0
# Product Url          0
# Is Amazon Seller     0
# dtype: int64

# %%
product_data['Selling Price'].dtype
# Out:
# dtype('O')

# %% [markdown]
# # Merging the 3 tables:

# %%
merged_data = pd.merge(sales_data, customer_data, left_on='user id', right_on='Customer ID', how='left')
merged_data = pd.merge(merged_data, product_data, left_on='product id', right_on='Uniqe Id', how='left')

# %%
merged_data
# Out:
#       user id                        product id Interaction type        Date  \
# 0           1  4c69b61db1fc16e7013b43fc926e502d         purchase  10/10/2023
# 1           2  66d49bbed043f5be260fa9f7fbff5957             view  11/10/2023
# 2           3  2c55cae269aebf53838484b0d7dd931a             like  12/10/2023
# 3           4  18018b6bc416dab347b1b7db79994afa             view  13/10/2023
# 4           5  e04b990e95bf73bbe6a3fa09785d7cd0             like  14/10/2023
# ...       ...                               ...              ...         ...
# 2995     2996  82318e8acf79bbeb3cf685a2732fb630             view  16/12/2023
# 2996     2997  19d150365d798db47cccf1622b6ad754         purchase  17/12/2023
# 2997     2998  136c0aff3ab56bd3d138775fe90ef970             view  18/12/2023
# 2998     2999  a2c6dd69f022a658c5bcc2b3b52970f2             like  19/12/2023
# 2999        1  0000fe97fd6c7705b08b7f4c7c5312ce             like  10/10/2023
#
# ...

# %%
merged_data.columns
# Out:
# Index(['user id', 'product id', 'Interaction type', 'Date', 'Time',
#        'Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category_x',
#        'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Shipping Type',
#        'Discount Applied', 'Promo Code Used', 'Previous Purchases',
#        'Payment Method', 'Frequency of Purchases', 'Uniqe Id', 'Product Name',
#        'Category_y', 'Selling Price', 'About Product', 'Technical Details',
#        'Image', 'Product Url', 'Is Amazon Seller'],
#       dtype='object')

# %%
merged_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3000 entries, 0 to 2999
# Data columns (total 32 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   user id                 3000 non-null   int64
#  1   product id              3000 non-null   object
#  2   Interaction type        3000 non-null   object
#  3   Date                    3000 non-null   object
#  4   Time                    3000 non-null   object
#  5   Customer ID             3000 non-null   int64
#  6   Age                     3000 non-null   int64
#  7   Gender                  3000 non-null   object
#  8   Item Purchased          3000 non-null   object
#  9   Category_x              3000 non-null   object
#  10  Purchase Amount (USD)   3000 non-null   int64
#  11  Location                3000 non-null   object
#  12  Size                    3000 non-null   object
#  13  Color                   3000 non-null   object
# ...

# %%
merged_data['Category_y']
# Out:
# 0       Sports & Outdoors | Outdoor Recreation | Skate...
# 1       Toys & Games | Learning & Education | Science ...
# 2               Toys & Games | Arts & Crafts | Craft Kits
# 3       Toys & Games | Hobbies | Models & Model Kits |...
# 4                 Toys & Games | Puzzles | Jigsaw Puzzles
#                               ...
# 2995    Toys & Games | Stuffed Animals & Plush Toys | ...
# 2996    Toys & Games | Hobbies | Remote & App Controll...
# 2997    Toys & Games | Hobbies | Models & Model Kits |...
# 2998    Toys & Games | Toy Figures & Playsets | Action...
# 2999     Toys & Games | Games & Accessories | Board Games
# Name: Category_y, Length: 3000, dtype: object

# %%
merged_data['Category_x']
# Out:
# 0          Clothing
# 1          Clothing
# 2          Clothing
# 3          Footwear
# 4          Clothing
#            ...
# 2995       Clothing
# 2996    Accessories
# 2997       Clothing
# 2998       Clothing
# 2999       Clothing
# Name: Category_x, Length: 3000, dtype: object

# %%
merged_data['Previous Purchases']
# Out:
# 0       14
# 1        2
# 2       23
# 3       49
# 4       31
#         ..
# 2995    42
# 2996     6
# 2997    14
# 2998    30
# 2999    14
# Name: Previous Purchases, Length: 3000, dtype: int64

# %%
merged_data['Item Purchased']
# Out:
# 0        Blouse
# 1       Sweater
# 2         Jeans
# 3       Sandals
# 4        Blouse
#          ...
# 2995      Jeans
# 2996    Jewelry
# 2997    Sweater
# 2998     Hoodie
# 2999     Blouse
# Name: Item Purchased, Length: 3000, dtype: object

# %%
merged_data['Review Rating']
# Out:
# 0       3.1
# 1       3.1
# 2       3.1
# 3       3.5
# 4       2.7
#        ...
# 2995    2.5
# 2996    2.9
# 2997    2.7
# 2998    4.7
# 2999    3.1
# Name: Review Rating, Length: 3000, dtype: float64
